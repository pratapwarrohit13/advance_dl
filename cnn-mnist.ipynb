# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.datasets import mnist

# %%
(features_train, target_train), (features_test, target_test) = mnist.load_data()
num_labels = len(np.unique(target_train))

# convert to one-hot vector
target_train = to_categorical(target_train)
target_test = to_categorical(target_test)
image_size = features_train.shape[1]
features_train= np.reshape(features_train,[-1, image_size, image_size, 1])
features_test = np.reshape(features_test,[-1, image_size, image_size, 1])
features_train = features_train.astype('float32') / 255
features_test = features_test.astype('float32') / 255

# %%
input_shape = (image_size, image_size, 1)
batch_size = 128
kernel_size = 3
pool_size = 2
filters = 64
dropout = 0.2

# %%
model = Sequential()
model.add(Conv2D(filters=filters,
                 kernel_size=kernel_size,
                 activation='relu',
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size))
model.add(Conv2D(filters=filters,
                 kernel_size=kernel_size,
                 activation='relu'))
model.add(MaxPooling2D(pool_size))
model.add(Conv2D(filters=filters,
                 kernel_size=kernel_size,
                 activation='relu'))
model.add(Flatten())
# dropout added as regularizer
model.add(Dropout(dropout))
# output layer is 10-dim one-hot vector
model.add(Dense(num_labels))
model.add(Activation('softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 26, 26, 64)        640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 576)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5770
# _________________________________________________________________
# activation_1 (Activation)    (None, 10)                0
# =================================================================
# Total params: 80,266
# Trainable params: 80,266
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.fit(features_train, target_train, epochs=100, batch_size=batch_size)
# Out:
# Epoch 1/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.5936 - accuracy: 0.8220
# Epoch 2/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0788 - accuracy: 0.9748
# Epoch 3/100
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0545 - accuracy: 0.9825
# Epoch 4/100
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0414 - accuracy: 0.9868
# Epoch 5/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0331 - accuracy: 0.9895
# Epoch 6/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0286 - accuracy: 0.9909
# Epoch 7/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0235 - accuracy: 0.9928
# Epoch 8/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0223 - accuracy: 0.9925
# Epoch 9/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0183 - accuracy: 0.9943
# Epoch 10/100
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0174 - accuracy: 0.9951
# Epoch 11/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0132 - accuracy: 0.9955
# Epoch 12/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0154 - accuracy: 0.9949
# Epoch 13/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0123 - accuracy: 0.9960
# Epoch 14/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0113 - accuracy: 0.9963
# Epoch 15/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0103 - accuracy: 0.9961
# Epoch 16/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0107 - accuracy: 0.9966
# Epoch 17/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0083 - accuracy: 0.9973
# Epoch 18/100
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0062 - accuracy: 0.9979
# Epoch 19/100
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0082 - accuracy: 0.9972
# Epoch 20/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0072 - accuracy: 0.9978
# Epoch 21/100
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0076 - accuracy: 0.9973
# Epoch 22/100
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0079 - accuracy: 0.9974
# Epoch 23/100
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0058 - accuracy: 0.9979
# Epoch 24/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0067 - accuracy: 0.9977
# Epoch 25/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0073 - accuracy: 0.9976
# Epoch 26/100
# 469/469 [==============================] - 38s 82ms/step - loss: 0.0037 - accuracy: 0.9988
# Epoch 27/100
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0051 - accuracy: 0.9983
# Epoch 28/100
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0044 - accuracy: 0.9983
# Epoch 29/100
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0047 - accuracy: 0.9983
# Epoch 30/100
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0044 - accuracy: 0.9983
# Epoch 31/100
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0041 - accuracy: 0.9984
# Epoch 32/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0033 - accuracy: 0.9988
# Epoch 33/100
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0035 - accuracy: 0.9990
# Epoch 34/100
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0048 - accuracy: 0.9984
# Epoch 35/100
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0037 - accuracy: 0.9987
# Epoch 36/100
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0035 - accuracy: 0.9988
# Epoch 37/100
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0027 - accuracy: 0.9991
# Epoch 38/100
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0035 - accuracy: 0.9989
# Epoch 39/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0044 - accuracy: 0.9983
# Epoch 40/100
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0043 - accuracy: 0.9986
# Epoch 41/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0036 - accuracy: 0.9985
# Epoch 42/100
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0037 - accuracy: 0.9984
# Epoch 43/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0026 - accuracy: 0.9992
# Epoch 44/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0028 - accuracy: 0.9991
# Epoch 45/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0037 - accuracy: 0.9985
# Epoch 46/100
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0026 - accuracy: 0.9991
# Epoch 47/100
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0030 - accuracy: 0.9990
# Epoch 48/100
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0027 - accuracy: 0.9990
# Epoch 49/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0022 - accuracy: 0.9991
# Epoch 50/100
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0018 - accuracy: 0.9993
# Epoch 51/100
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0041 - accuracy: 0.9987
# Epoch 52/100
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0027 - accuracy: 0.9989
# Epoch 53/100
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0023 - accuracy: 0.9992
# Epoch 54/100
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0010 - accuracy: 0.9997
# Epoch 55/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0032 - accuracy: 0.9990
# Epoch 56/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0026 - accuracy: 0.9991
# Epoch 57/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0026 - accuracy: 0.9989
# Epoch 58/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0040 - accuracy: 0.9988
# Epoch 59/100
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0022 - accuracy: 0.9992
# Epoch 60/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0029 - accuracy: 0.9990
# Epoch 61/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0027 - accuracy: 0.9991
# Epoch 62/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0026 - accuracy: 0.9992
# Epoch 63/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0033 - accuracy: 0.9988
# Epoch 64/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 65/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0027 - accuracy: 0.9990
# Epoch 66/100
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0027 - accuracy: 0.9992
# Epoch 67/100
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0017 - accuracy: 0.9994
# Epoch 68/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0025 - accuracy: 0.9991
# Epoch 69/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0022 - accuracy: 0.9993
# Epoch 70/100
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0021 - accuracy: 0.9991
# Epoch 71/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0030 - accuracy: 0.9989
# Epoch 72/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0015 - accuracy: 0.9994
# Epoch 73/100
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0031 - accuracy: 0.9991
# Epoch 74/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0019 - accuracy: 0.9993
# Epoch 75/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0015 - accuracy: 0.9994
# Epoch 76/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0026 - accuracy: 0.9992
# Epoch 77/100
# 469/469 [==============================] - 37s 79ms/step - loss: 9.9980e-04 - accuracy: 0.9997
# Epoch 78/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0022 - accuracy: 0.9994
# Epoch 79/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0024 - accuracy: 0.9992
# Epoch 80/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0025 - accuracy: 0.9992
# Epoch 81/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0023 - accuracy: 0.9993
# Epoch 82/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0020 - accuracy: 0.9994
# Epoch 83/100
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0023 - accuracy: 0.9995
# Epoch 84/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0021 - accuracy: 0.9992
# Epoch 85/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0012 - accuracy: 0.9996
# Epoch 86/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0020 - accuracy: 0.9994
# Epoch 87/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0021 - accuracy: 0.9994
# Epoch 88/100
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0022 - accuracy: 0.9992
# Epoch 89/100
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0025 - accuracy: 0.9992
# Epoch 90/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0025 - accuracy: 0.9993
# Epoch 91/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0026 - accuracy: 0.9992
# Epoch 92/100
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0022 - accuracy: 0.9992
# Epoch 93/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 94/100
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0022 - accuracy: 0.9992
# Epoch 95/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0016 - accuracy: 0.9994
# Epoch 96/100
# 469/469 [==============================] - 36s 78ms/step - loss: 0.0020 - accuracy: 0.9994
# Epoch 97/100
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0026 - accuracy: 0.9992
# Epoch 98/100
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0016 - accuracy: 0.9994
# Epoch 99/100
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0018 - accuracy: 0.9992
# Epoch 100/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0037 - accuracy: 0.9991

# %%
_, acc = model.evaluate(features_test,
                        target_test,
                        batch_size=batch_size,
                        verbose=0)
print("\nTest accuracy: %.1f%%" % (100.0 * acc))
# Out:
# Test accuracy: 99.4%
